# %%
import akshare as ak

# %%
ak.fund_name_em()
# Out:
#          基金代码                  拼音缩写                  基金简称      基金类型  \
# 0      000001                HXCZHH                华夏成长混合    混合型-灵活
# 1      000002                HXCZHH            华夏成长混合(后端)    混合型-灵活
# 2      000003              ZHKZZZQA              中海可转债债券A  债券型-混合二级
# 3      000004              ZHKZZZQC              中海可转债债券C  债券型-混合二级
# 4      000005            JSZQXYDQZQ            嘉实增强信用定期债券  债券型-混合一级
# ...       ...                   ...                   ...       ...
# 26354  970192         XZZGJQLXJTLHB         兴证资管金麒麟现金添利货币  货币型-普通货币
# 26355  970194        XZZGJQL3GYFOFA      兴证资管金麒麟3个月(FOF)A   FOF-进取型
# 26356  970195        XZZGJQL3GYFOFC      兴证资管金麒麟3个月(FOF)C   FOF-进取型
# 26357  970204  XZZGJQLXXZLLGYCYQZQA  兴证资管金麒麟兴享增利六个月持有期债券A  债券型-混合二级
# 26358  970205  XZZGJQLXXZLLGYCYQZQC  兴证资管金麒麟兴享增利六个月持有期债券C  债券型-混合二级
#
#                                                     拼音全称
# 0                                  HUAXIACHENGZHANGHUNHE
# ...

# %%
ak.fund_open_fund_daily_em()
# Out:
#          基金代码            基金简称 2026-03-31-单位净值 2026-03-31-累计净值 2026-03-30-单位净值  \
# 0      011598       信澳医药健康混合A          1.2004          1.2004          1.1623
# 1      024171       信澳医药健康混合C          1.1957          1.1957          1.1578
# 2      161226  国投瑞银白银期货(LOF)A          2.0411          2.0411          1.9832
# 3      019005  国投瑞银白银期货(LOF)C          2.0214          2.0214           1.964
# 4      024172        信澳中小盘混合C           1.748           1.748           1.702
# ...       ...             ...             ...             ...             ...
# 22993  026987   汇泉科创创业量化选股混合C
# 22994  026934    鑫元周期睿选混合发起式C
# 22995  026933    鑫元周期睿选混合发起式A
# 22996  026677       创金合信弘达债券C
# 22997  026676       创金合信弘达债券A
#
#       2026-03-30-累计净值    日增长值  日增长率  申购状态  赎回状态    手续费
# 0              1.1623  0.0381  3.28   限大额  开放赎回  0.15%
# 1              1.1578  0.0379  3.27   限大额  开放赎回  0.00%
# 2              1.9832  0.0579  2.92  暂停申购  开放赎回  0.10%
# ...

# %%
ak.fund_open_fund_info_em(symbol='002207', indicator="单位净值走势")
# Out:
#             净值日期   单位净值    日增长率
# 0     2015-12-02  1.000  0.0000
# 1     2015-12-03  1.003  0.3000
# 2     2015-12-04  1.003  0.0000
# 3     2015-12-07  1.004  0.0997
# 4     2015-12-08  1.003 -0.0996
# ...          ...    ...     ...
# 2513  2026-03-27  2.793  2.8400
# 2514  2026-03-30  2.881  3.1500
# 2515  2026-03-31  2.883  0.0700
# 2516  2026-04-01  2.950  2.3200
# 2517  2026-04-02  2.863 -2.9500
#
# [2518 rows x 3 columns]

# %%
ak.fund_open_fund_info_em(symbol='002207', indicator="累计净值走势")
# Out:
#             净值日期   累计净值
# 0     2015-12-02  1.000
# 1     2015-12-03  1.003
# 2     2015-12-04  1.003
# 3     2015-12-07  1.004
# 4     2015-12-08  1.003
# ...          ...    ...
# 2513  2026-03-27  2.793
# 2514  2026-03-30  2.881
# 2515  2026-03-31  2.883
# 2516  2026-04-01  2.950
# 2517  2026-04-02  2.863
#
# [2518 rows x 2 columns]

# %%
ak.fund_value_estimation_em('全部')
# Out:
#           序号    基金代码            基金名称 2026-03-31-估算数据-估算值  \
# 0          1  025486  中邮新锐量化选股混合发起式A              1.1054
# 1          2  025487  中邮新锐量化选股混合发起式C              1.1028
# 2          3  025447  万家元晟量化选股混合发起式A              1.2101
# 3          4  025448  万家元晟量化选股混合发起式C              1.2069
# 4          5  011598       信澳医药健康混合A              1.1977
# ...      ...     ...             ...                 ...
# 19995  19996  000524       摩根民生需求股票A              2.5138
# 19996  19997  000603   易方达创新驱动灵活配置混合              2.3469
# 19997  19998  010264       鹏华成长智选混合A              1.0263
# 19998  19999  011488       申万菱信乐享混合A              1.5082
# 19999  20000  011668       东财高端制造增强C              1.1548
#
#       2026-03-31-估算数据-估算增长率 2026-03-31-公布数据-单位净值 2026-03-31-公布数据-日增长率    估算偏差  \
# 0                     3.43%               1.0557               -1.22%   4.65%
# 1                     3.43%               1.0532               -1.22%   4.65%
# ...

# %%
ak.fund_portfolio_hold_em('002207', '2025')
# Out:
#     序号    股票代码  股票名称  占净值比例      持股数      持仓市值              季度
# 0    1  601069  西部黄金   9.34   986.83  16618.22  2025年1季度股票投资明细
# 1    2  600988  赤峰黄金   9.16   711.29  16288.47  2025年1季度股票投资明细
# 2    3  601899  紫金矿业   8.73   857.09  15530.38  2025年1季度股票投资明细
# 3    4  000975  山金国际   8.73   808.26  15518.58  2025年1季度股票投资明细
# 4    5  600547  山东黄金   8.48   561.00  15079.63  2025年1季度股票投资明细
# 5    6  600489  中金黄金   7.99  1010.12  14212.43  2025年1季度股票投资明细
# 6    7  002237  恒邦股份   7.99  1252.83  14207.05  2025年1季度股票投资明细
# 7    8  600961  株冶集团   7.82  1458.18  13911.04  2025年1季度股票投资明细
# 8    9  002155  湖南黄金   7.73   601.18  13749.02  2025年1季度股票投资明细
# 9   10  000603  盛达资源   7.73   875.84  13741.99  2025年1季度股票投资明细
# 10  11  601899  紫金矿业   9.22   911.34  17771.03  2025年2季度股票投资明细
# 11  12  600547  山东黄金   8.88   536.05  17116.23  2025年2季度股票投资明细
# 12  13  002155  湖南黄金   8.79   949.58  16949.95  2025年2季度股票投资明细
# 13  14  000975  山金国际   8.73   888.35  16825.34  2025年2季度股票投资明细
# ...

# %%
pd1 = ak.fund_portfolio_industry_allocation_em(symbol="002207", date="2025")

# %%
pd1[pd1['截止时间'] > '2025-06-30'][['行业类别', '占净值比例', '截止时间']]
# Out:
#   行业类别  占净值比例        截止时间
# 0  采矿业  84.13  2025-12-31
# 1  制造业   8.04  2025-12-31
# 2  采矿业  83.86  2025-09-30
# 3  制造业   9.63  2025-09-30

# %%
ak.fund_individual_achievement_xq(symbol='002207')
# Out:
#     业绩类型    周期     本产品区间收益  本产品最大回撒   周期收益同类排名
# 0   年度业绩  成立以来  188.300000    49.55   294/2145
# 1   年度业绩  今年以来   15.412330    33.44    62/2145
# 2   年度业绩  2025   86.700000    16.49    49/2142
# 3   年度业绩  2024    2.840000    22.63  1204/2138
# 4   年度业绩  2023    7.880000    18.09    71/2125
# 5   年度业绩  2022    4.150000    19.95    49/2021
# 6   年度业绩  2021   -3.740000    17.98  1667/1909
# 7   年度业绩  2020   14.790000    22.48  1437/1778
# 8   年度业绩  2019   28.910000    19.14   787/1679
# 9   年度业绩  2018  -15.400000    31.46   820/1566
# 10  年度业绩  2017  -15.780000    21.94  1300/1316
# 11  年度业绩  2016   13.530000    22.81    23/1035
# 12  年度业绩  2015    0.200000      NaN    509/624
# 13  阶段业绩   近1月  -14.830133      NaN  2083/2145
# 14  阶段业绩   近3月   15.412330    33.44    61/2142
# 15  阶段业绩   近6月   18.349754    33.44    86/2134
# 16  阶段业绩   近1年   74.199396    33.44    99/2105
# 17  阶段业绩   近3年  103.028169    33.44    36/1930
# 18  阶段业绩   近5年  148.534483    33.44    31/1696

# %%
ak.fund_open_fund_daily_em()
# Out:
#          基金代码                基金简称 2026-04-02-单位净值 2026-04-02-累计净值  \
# 0      023144  汇添富中证油气资源ETF发起式联接A          1.5731          1.5731
# 1      023145  汇添富中证油气资源ETF发起式联接C          1.5705          1.5705
# 2      021855   博时中证油气资源ETF发起式联接A          1.4124          1.4124
# 3      021856   博时中证油气资源ETF发起式联接C          1.4081          1.4081
# 4      008425           国联品牌优选混合C          0.5792          0.5792
# ...       ...                 ...             ...             ...
# 22987  026934        鑫元周期睿选混合发起式C
# 22988  026933        鑫元周期睿选混合发起式A
# 22989  026677           创金合信弘达债券C
# 22990  026676           创金合信弘达债券A
# 22991  026705         方正富邦恒信双利债券A
#
#       2026-04-01-单位净值 2026-04-01-累计净值    日增长值  日增长率  申购状态  赎回状态    手续费
# 0              1.5157          1.5157  0.0574  3.79  开放申购  开放赎回  0.10%
# 1              1.5132          1.5132  0.0573  3.79  开放申购  开放赎回  0.00%
# 2              1.3623          1.3623  0.0501  3.68   限大额  开放赎回  0.10%
# ...

# %%
ak.fund_open_fund_rank_em()
# Out:
#           序号    基金代码                      基金简称          日期    单位净值    累计净值  \
# 0          1  022364               永赢科技智选混合发起A  2026-04-02  3.8018  3.8018
# 1          2  022365               永赢科技智选混合发起C  2026-04-02  3.7687  3.7687
# 2          3  011369                 华商均衡成长混合A  2026-04-02  2.5514  2.5514
# 3          4  011370                 华商均衡成长混合C  2026-04-02  2.4765  2.4765
# 4          5  008528                 华泰柏瑞质量成长A  2026-04-02  2.2263  2.2263
# ...      ...     ...                       ...         ...     ...     ...
# 16666  16667  025308             国泰海通中证全指指数增强A  2026-04-02  1.0483  1.0483
# 16667  16668  023679            格林上证科创板综合指数增强A  2026-04-02  1.0001  1.0001
# 16668  16669  026970                   泓德裕康债券D  2026-04-02  1.3956  1.3956
# 16669  16670  025046  永赢元享稳健多资产90天持有混合发起(FOF)A  2026-03-31  1.0287  1.0287
# 16670  16671  024193     国投瑞银中证全指公用事业ETF发起式联接C  2026-04-02  1.0643  1.0643
#
# ...
